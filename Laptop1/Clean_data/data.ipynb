# %%
'''
import pandas as pd
import os

# Path to the folder containing the CSV files
data_folder = "D:/Laptop/Data"

# List of CSV filenames
file_list = [
    "laptop_data.csv",
    "cpu_specs.csv",
    "material.csv",
    "Port.csv",
    "Ram.csv",
    "Screen.csv",
    "Sound.csv"
]


full_paths = [os.path.join(data_folder, filename) for filename in file_list]

dataframes = {
    os.path.basename(path): pd.read_csv(path, encoding='utf-8-sig')
    for path in full_paths
}


main_df = dataframes["laptop_data.csv"]


for filename, df in dataframes.items():
    if filename != "laptop_data.csv":
        main_df = pd.merge(main_df, df, on="Link", how="left")
data_output = "D:/Laptop/Clean_data"

output_path = os.path.join(data_output, "merged_laptop_data.csv")
main_df.to_csv(output_path, index=False, encoding='utf-8-sig')

print(f" Merge completed! Output file saved at: {output_path}")
'''
# Out:
#  Merge completed! Output file saved at: D:/Laptop/Clean_data\merged_laptop_data.csv

# %%
'''df = pd.read_csv("D:/Laptop/Data/merged_laptop_data.csv", encoding='utf-8-sig')
missing_rows = df[df.isnull().any(axis=1)]
print(f"Số hàng có dữ liệu thiếu: {len(missing_rows)}")
print(missing_rows.head())'''
# Out:
# Số hàng có dữ liệu thiếu: 26
#                                                  name     Model        price  \
# 1   Laptop MSI Gaming Katana 15 B13UDXK i7 13620H/...       MSI     Không có
# 13  Laptop Acer Aspire Lite 16 G2 AL16 52P 76DU i7...      Acer  17.990.000₫
# 34  Laptop Asus Zenbook 14 OLED UX3405MA Ultra 5 1...      Asus  28.990.000₫
# 42       Laptop MacBook Pro 14 inch M4 Pro 24GB/512GB   MacBook     Không có
# 52  Laptop GIGABYTE G5 MF5 RC555 i5 13500H/16GB/51...  GIGABYTE     Không có
#
#      Giá hiện tại Khuyến mãi  \
# 1        Không có   Không có
# 13    16.990.000₫        -5%
# 34  26.990.000₫ *        -6%
# 42    49.990.000₫   Không có
# 52    21.990.000₫   Không có
#
#                                                  link  \
# 1   //www.thegioididong.com/laptop/msi-katana-15-b...
# 13  //www.thegioididong.com/laptop/acer-aspire-lit...
# 34  //www.thegioididong.com/laptop/asus-zenbook-14...
# 42  //www.thegioididong.com/laptop/macbook-pro-14-...
# ...

# %%
import pandas as pd

df = pd.read_csv("D:/Laptop1/Data/merged_laptop_data.csv", encoding="utf-8-sig")

rename_dict = {
    "name": "name",
    "Model": "model",
    "price": "price",
    "Giá hiện tại": "current_price",
    "Khuyến mãi": "discount",
    "Link": "link",
    "Mô tả": "description",
    "CPU": "cpu",
    "Số nhân": "cores",
    "Số luồng": "threads",
    "Tốc độ CPU": "cpu_speed",
    "Tốc độ tối đa": "max_speed",
    "Kich_thuoc": "size",
    "Chat_lieu": "material",
    "He_thong_pin": "battery",
    "He_dieu_hanh": "os",
    "Thoi_gian_ra_mat": "release_time",
    "Cong_Giao_tiep": "ports",
    "Wireless": "wireless",
    "Webcams": "webcams",
    "Features": "features",
    "Den_ban_phim": "keyboard_backlight",
    "RAM": "ram",
    "Ram Speed": "ram_speed",
    "Ram Max": "ram_max",
    "Hard Drive": "hard_drive",
    "Review": "review",
    "Image": "image",
    "Screen": "screen",
    "Do_phan_giais": "resolution",
    "Tan_so_quets": "refresh_rate",
    "Do_phu_mau": "color_coverage",
    "Screen_Technologys": "screen_tech",
    "Card_Screen": "gpu",
    "Technology_Sound": "sound_tech"
}

df.rename(columns=rename_dict, inplace=True)

# Xóa các dòng không có 'link'
df = df[df["link"].notnull() & (df["link"].str.strip() != "")]

# Làm sạch giá trị thiếu bằng "no <english_column_name>"
def clean_column_dynamic(col, col_name):
    default_value = f"no {col_name}"
    return col.fillna(default_value).replace(
        ["no"], default_value
    )

for col in df.columns:
    df[col] = clean_column_dynamic(df[col], col)

df.to_csv("cleaned_laptop_data.csv", index=False, encoding="utf-8-sig")
print("✅ Done: File cleaned and saved as 'cleaned_laptop_data_en.csv'")
# Out:
# ✅ Done: File cleaned and saved as 'cleaned_laptop_data_en.csv'

# %%
df = df[df['price'].notnull()]
df = df[~df['price'].astype(str).str.contains("Không có")]

# Cột Link: bỏ dòng nếu thiếu
df = df[df['Link'].notnull() & (df['Link'] != "")]

# Điền mặc định cho các cột mô tả
default_values = {
    'CPU': 'Không rõ',
    'RAM': 'Không rõ',
    'Screen': 'Không rõ',
    'Card_Screen': 'Không rõ',
    'Review': 'Không ',
    'Mô tả': ''
}
df.fillna(value=default_values, inplace=True)
